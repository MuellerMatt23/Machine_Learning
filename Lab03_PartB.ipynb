# %% [markdown]
# Question 1

# %%
import pandas as pd

housing = pd.read_csv("/content/housing.csv")

housing.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
# split data to get train and test set
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=10)

# %%
# clean missing values
train_set_clean = train_set.dropna(subset = ["total_bedrooms"])
train_set_clean
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12346    -116.52     33.82                21.0      10227.0          2315.0
# 19326    -122.94     38.50                46.0       2280.0           492.0
# 16824    -122.49     37.63                31.0       3109.0           621.0
# 6869     -118.11     34.06                16.0       2416.0           565.0
# 16677    -120.66     35.13                41.0       2666.0           751.0
# ...          ...       ...                 ...          ...             ...
# 9372     -122.53     37.93                37.0       1722.0           352.0
# 7291     -118.22     33.98                18.0       1781.0           765.0
# 17728    -121.79     37.32                 6.0       2850.0           561.0
# 7293     -118.23     33.98                35.0       1366.0           496.0
# 17673    -121.88     37.30                16.0       2692.0           749.0
#
# ...

# %%
# derive trianing features and training labels
trian_labels = train_set_clean["median_house_value"].copy()
train_features = train_set_clean.drop("median_house_value", axis=1)

# %%
# scale the numeric features in the training set
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train_features)

train_features_normalized = scaler.transform(train_features)
train_features_normalized
# Out:
# array([[0.77988048, 0.1360255 , 0.39215686, ..., 0.10146024, 0.28498602,
#         0.13939808],
#        [0.14043825, 0.63336876, 0.88235294, ..., 0.02253426, 0.06002302,
#         0.14701177],
#        [0.18525896, 0.54091392, 0.58823529, ..., 0.04117268, 0.10146358,
#         0.32103695],
#        ...,
#        [0.25498008, 0.50797024, 0.09803922, ..., 0.06045573, 0.09537905,
#         0.34714694],
#        [0.60956175, 0.15302869, 0.66666667, ..., 0.06045573, 0.08156553,
#         0.11765355],
#        [0.24601594, 0.50584485, 0.29411765, ..., 0.04683427, 0.11182371,
#         0.15009448]])

# %%
# Task: Apply these techniques to the test data
# clean missing values
test_set_clean = test_set.dropna(subset = ["total_bedrooms"])
test_set_clean
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20303    -119.18     34.16                12.0        460.0           101.0
# 16966    -122.31     37.55                27.0       3931.0           933.0
# 10623    -117.77     33.67                12.0       4329.0          1068.0
# 6146     -117.95     34.11                29.0       1986.0           448.0
# 2208     -119.87     36.81                 6.0       1891.0           341.0
# ...          ...       ...                 ...          ...             ...
# 3263     -122.88     39.14                20.0       1125.0           231.0
# 11694    -117.98     33.89                18.0       2939.0           437.0
# 1729     -122.34     37.98                33.0       2014.0           410.0
# 5087     -118.28     33.98                45.0       1720.0           416.0
# 6581     -118.20     34.21                40.0       1477.0           228.0
#
# ...

# %%
# derive trianing features and training labels
test_labels = test_set_clean["median_house_value"].copy()
test_features = test_set_clean.drop("median_house_value", axis=1)

# %%
scaler = MinMaxScaler()
scaler.fit(train_features)
test_features_normalized = scaler.transform(test_features)
test_features_normalized
# Out:
# array([[0.51494024, 0.17215728, 0.21568627, ..., 0.01126713, 0.01677356,
#         0.32954028],
#        [0.20318725, 0.53241233, 0.50980392, ..., 0.05252389, 0.13977964,
#         0.23946566],
#        [0.65537849, 0.12008502, 0.21568627, ..., 0.05353289, 0.16066436,
#         0.27651343],
#        ...,
#        [0.2001992 , 0.5781084 , 0.62745098, ..., 0.03786541, 0.07005427,
#         0.23981738],
#        [0.60458167, 0.15302869, 0.8627451 , ..., 0.03865019, 0.05985858,
#         0.02991683],
#        [0.6125498 , 0.17747078, 0.76470588, ..., 0.01698478, 0.0366716 ,
#         0.5060344 ]])

# %% [markdown]
# Question 2

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
############################################################################
import time
start_time = time.time()

KNN_regressor = KNeighborsRegressor(n_neighbors=10, metric = 'euclidean')
KNN_regressor.fit(train_features_normalized, trian_labels)

end_time = time.time()
elapsed_time = end_time - start_time
print("Running time: ", elapsed_time, "seconds")
# Out:
# Running time:  0.07474255561828613 seconds

# %% [markdown]
# Question 3

# %%
training_predictions = KNN_regressor.predict(train_features_normalized)
training_predictions
# Out:
# array([117520. , 179180. , 349970.1, ..., 254950. , 150750. , 187270. ])

# %%
training_predictions.shape
# Out:
# (16346,)

# %%
trian_labels.shape
# Out:
# (16346,)

# %% [markdown]
# Question 4

# %%
import pandas as pd
prediction_summary = pd.DataFrame({'predicted_label':training_predictions, 'actual_label':trian_labels})
prediction_summary
# Out:
#        predicted_label  actual_label
# 12346         117520.0      145200.0
# 19326         179180.0      117000.0
# 16824         349970.1      263900.0
# 6869          161640.0      163700.0
# 16677         167120.0      236100.0
# ...                ...           ...
# 9372          263180.0      310300.0
# 7291          176630.0      255000.0
# 17728         254950.0      241900.0
# 7293          150750.0      150000.0
# 17673         187270.0      191100.0
#
# [16346 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
prediction_summary.plot.scatter(x='predicted_label', y='actual_label', color='blue', marker='o')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Predicted Label vs Actual Label for Training Data')
plt.show()

# %%
import numpy as np
np.corrcoef(training_predictions, trian_labels)
# Out:
# array([[1.        , 0.87566661],
#        [0.87566661, 1.        ]])

# %% [markdown]
# Question 5

# %%
prediction_summary['error'] = prediction_summary['actual_label'] - prediction_summary['predicted_label']
prediction_summary
# Out:
#        predicted_label  actual_label    error
# 12346         117520.0      145200.0  27680.0
# 19326         179180.0      117000.0 -62180.0
# 16824         349970.1      263900.0 -86070.1
# 6869          161640.0      163700.0   2060.0
# 16677         167120.0      236100.0  68980.0
# ...                ...           ...      ...
# 9372          263180.0      310300.0  47120.0
# 7291          176630.0      255000.0  78370.0
# 17728         254950.0      241900.0 -13050.0
# 7293          150750.0      150000.0   -750.0
# 17673         187270.0      191100.0   3830.0
#
# [16346 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error
lin_mse = mean_squared_error(trian_labels, training_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 55743.33849539552

# %% [markdown]
# Question 6

# %%
from sklearn.neighbors import KNeighborsRegressor
KNN_regressor = KNeighborsRegressor(n_neighbors=7, metric='euclidean')

# %%
from sklearn.model_selection import cross_val_score
CV_mse_scores = cross_val_score(estimator = KNN_regressor, X = train_features_normalized, y = trian_labels, cv = 10, scoring = 'neg_mean_squared_error')
print("CV_mse_scores: ", CV_mse_scores)
# Out:
# CV_mse_scores:  [-3.91841608e+09 -4.10790086e+09 -3.59604082e+09 -3.81505352e+09
#  -4.08762578e+09 -3.83463385e+09 -4.10664865e+09 -3.77413013e+09
#  -3.73180413e+09 -4.15740833e+09]

# %%
def display_scores(scores):
  print("CV_scores: ", scores)
  print("CV_mean: ", scores.mean())
  print("CV Standard Deviation: ", scores.std())

# %%
display_scores(CV_mse_scores)
# Out:
# CV_scores:  [-3.91841608e+09 -4.10790086e+09 -3.59604082e+09 -3.81505352e+09
#  -4.08762578e+09 -3.83463385e+09 -4.10664865e+09 -3.77413013e+09
#  -3.73180413e+09 -4.15740833e+09]
# CV_mean:  -3912966215.784583
# CV Standard Deviation:  182773010.66517955

# %%
CV_r2_scores = cross_val_score(estimator = KNN_regressor,
                               X = train_features_normalized,
                               y = trian_labels,
                               cv = 10,
                               scoring ='r2')
print("CV_r2_scores: ", CV_r2_scores)
# Out:
# CV_r2_scores:  [0.69080821 0.70565108 0.71749391 0.69946592 0.69684798 0.71756461
#  0.69251691 0.71558565 0.72019134 0.68628121]

# %%
CV_r2_scores.mean()
# Out:
# 0.7042406815238087

# %%
CV_r2_scores.std()
# Out:
# 0.01206717541654081

# %%
data = [[10, 55743.338, 0.87566661, -3912966215.78, 182773010.66, 0.70424, 0.012067]]
performance_df = pd.DataFrame(data=data, columns=['K', 'Training MSE', 'Training Correlation', 'Mean of 10-Fold CV MSE', 'std of 10-Fold CV MSE', 'Mean of 10-Fold CV R2 scores', 'std of 10-fold R2 scores'])
performance_df
# Out:
#     K  Training MSE  Training Correlation  Mean of 10-Fold CV MSE  \
# 0  10     55743.338              0.875667           -3.912966e+09
#
#    std of 10-Fold CV MSE  Mean of 10-Fold CV R2 scores  \
# 0           1.827730e+08                       0.70424
#
#    std of 10-fold R2 scores
# 0                  0.012067

# %% [markdown]
# Question 7

# %%
# 3-Nearest Neighbors
import time
start_time = time.time()

KNN_regressor = KNeighborsRegressor(n_neighbors=3, metric = 'euclidean')
KNN_regressor.fit(train_features_normalized, trian_labels)

end_time = time.time()
elapsed_time = end_time - start_time
print("Running time: ", elapsed_time, "seconds")
# Out:
# Running time:  0.027689456939697266 seconds

# %%
training_predictions = KNN_regressor.predict(train_features_normalized)
training_predictions
# Out:
# array([136566.66666667, 149966.66666667, 275700.        , ...,
#        274600.        , 150000.        , 190900.        ])

# %%
training_predictions.shape
# Out:
# (16346,)

# %%
trian_labels.shape
# Out:
# (16346,)

# %%
import pandas as pd
prediction_summary = pd.DataFrame({'predicted_label':training_predictions, 'actual_label':trian_labels})
prediction_summary
# Out:
#        predicted_label  actual_label
# 12346    136566.666667      145200.0
# 19326    149966.666667      117000.0
# 16824    275700.000000      263900.0
# 6869     180500.000000      163700.0
# 16677    203133.333333      236100.0
# ...                ...           ...
# 9372     268300.000000      310300.0
# 7291     204633.333333      255000.0
# 17728    274600.000000      241900.0
# 7293     150000.000000      150000.0
# 17673    190900.000000      191100.0
#
# [16346 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
prediction_summary.plot.scatter(x='predicted_label', y='actual_label', color='blue', marker='o')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Predicted Label vs Actual Label for Training Data')
plt.show()

# %%
import numpy as np
np.corrcoef(training_predictions, trian_labels)
# Out:
# array([[1.        , 0.92096524],
#        [0.92096524, 1.        ]])

# %%
prediction_summary['error'] = prediction_summary['actual_label'] - prediction_summary['predicted_label']
prediction_summary
# Out:
#        predicted_label  actual_label         error
# 12346    136566.666667      145200.0   8633.333333
# 19326    149966.666667      117000.0 -32966.666667
# 16824    275700.000000      263900.0 -11800.000000
# 6869     180500.000000      163700.0 -16800.000000
# 16677    203133.333333      236100.0  32966.666667
# ...                ...           ...           ...
# 9372     268300.000000      310300.0  42000.000000
# 7291     204633.333333      255000.0  50366.666667
# 17728    274600.000000      241900.0 -32700.000000
# 7293     150000.000000      150000.0      0.000000
# 17673    190900.000000      191100.0    200.000000
#
# [16346 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error
lin_mse = mean_squared_error(trian_labels, training_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 44921.72441672835

# %%
CV_mse_scores = cross_val_score(estimator = KNN_regressor, X = train_features_normalized, y = trian_labels, cv = 10, scoring = 'neg_mean_squared_error')
print("CV_mse_scores: ", CV_mse_scores)
# Out:
# CV_mse_scores:  [-4.23722703e+09 -4.33221614e+09 -4.01473040e+09 -4.16385502e+09
#  -4.47043278e+09 -4.19915410e+09 -4.39235917e+09 -3.95327747e+09
#  -4.17509910e+09 -4.54230269e+09]

# %%
display_scores(CV_mse_scores)
# Out:
# CV_scores:  [-4.23722703e+09 -4.33221614e+09 -4.01473040e+09 -4.16385502e+09
#  -4.47043278e+09 -4.19915410e+09 -4.39235917e+09 -3.95327747e+09
#  -4.17509910e+09 -4.54230269e+09]
# CV_mean:  -4248065390.28994
# CV Standard Deviation:  178940010.04488206

# %%
CV_r2_scores = cross_val_score(estimator = KNN_regressor,
                               X = train_features_normalized,
                               y = trian_labels,
                               cv = 10,
                               scoring ='r2')
print("CV_r2_scores: ", CV_r2_scores)
# Out:
# CV_r2_scores:  [0.66565169 0.68957792 0.68460153 0.67198878 0.66845773 0.6907163
#  0.67112449 0.70208531 0.68695332 0.65723701]

# %%
CV_r2_scores.mean()
# Out:
# 0.6788394069479919

# %%
CV_r2_scores.std()
# Out:
# 0.013231006459082454

# %%
# Add values to dataframe
K_3_data =[[3, 44921.724, 0.92, -4248065390.28994, 178940010.04488206, 0.678839, 0.013231]]

K_3_df = pd.DataFrame(data=K_3_data, columns = performance_df.columns)

performance_df = pd.concat([performance_df, K_3_df], ignore_index=True)
performance_df
# Out:
#     K  Training MSE  Training Correlation  Mean of 10-Fold CV MSE  \
# 0  10     55743.338              0.875667           -3.912966e+09
# 1   3     44921.724              0.920000           -4.248065e+09
#
#    std of 10-Fold CV MSE  Mean of 10-Fold CV R2 scores  \
# 0           1.827730e+08                      0.704240
# 1           1.789400e+08                      0.678839
#
#    std of 10-fold R2 scores
# 0                  0.012067
# 1                  0.013231

# %%
# 5-Nearest Neighbors
import time
start_time = time.time()

KNN_regressor = KNeighborsRegressor(n_neighbors=5, metric = 'euclidean')
KNN_regressor.fit(train_features_normalized, trian_labels)

end_time = time.time()
elapsed_time = end_time - start_time
print("Running time: ", elapsed_time, "seconds")
# Out:
# Running time:  0.029465913772583008 seconds

# %%
training_predictions = KNN_regressor.predict(train_features_normalized)
training_predictions
# Out:
# array([117040. , 180840. , 318240.2, ..., 308440. , 145160. , 184940. ])

# %%
training_predictions.shape
# Out:
# (16346,)

# %%
trian_labels.shape
# Out:
# (16346,)

# %%
import pandas as pd
prediction_summary = pd.DataFrame({'predicted_label':training_predictions, 'actual_label':trian_labels})
prediction_summary
# Out:
#        predicted_label  actual_label
# 12346         117040.0      145200.0
# 19326         180840.0      117000.0
# 16824         318240.2      263900.0
# 6869          175420.0      163700.0
# 16677         165960.0      236100.0
# ...                ...           ...
# 9372          297720.0      310300.0
# 7291          183000.0      255000.0
# 17728         308440.0      241900.0
# 7293          145160.0      150000.0
# 17673         184940.0      191100.0
#
# [16346 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
prediction_summary.plot.scatter(x='predicted_label', y='actual_label', color='blue', marker='o')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Predicted Label vs Actual Label for Training Data')
plt.show()

# %%
import numpy as np
np.corrcoef(training_predictions, trian_labels)
# Out:
# array([[1.        , 0.89873576],
#        [0.89873576, 1.        ]])

# %%
prediction_summary['error'] = prediction_summary['actual_label'] - prediction_summary['predicted_label']
prediction_summary
# Out:
#        predicted_label  actual_label    error
# 12346         117040.0      145200.0  28160.0
# 19326         180840.0      117000.0 -63840.0
# 16824         318240.2      263900.0 -54340.2
# 6869          175420.0      163700.0 -11720.0
# 16677         165960.0      236100.0  70140.0
# ...                ...           ...      ...
# 9372          297720.0      310300.0  12580.0
# 7291          183000.0      255000.0  72000.0
# 17728         308440.0      241900.0 -66540.0
# 7293          145160.0      150000.0   4840.0
# 17673         184940.0      191100.0   6160.0
#
# [16346 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error
lin_mse = mean_squared_error(trian_labels, training_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 50586.62105352373

# %%
CV_mse_scores = cross_val_score(estimator = KNN_regressor, X = train_features_normalized, y = trian_labels, cv = 10, scoring = 'neg_mean_squared_error')
print("CV_mse_scores: ", CV_mse_scores)
# Out:
# CV_mse_scores:  [-4.00460628e+09 -4.19116646e+09 -3.74631586e+09 -3.94586509e+09
#  -4.27430173e+09 -3.86130000e+09 -4.21859526e+09 -3.74073072e+09
#  -3.81809645e+09 -4.33156853e+09]

# %%
display_scores(CV_mse_scores)
# Out:
# CV_scores:  [-4.00460628e+09 -4.19116646e+09 -3.74631586e+09 -3.94586509e+09
#  -4.27430173e+09 -3.86130000e+09 -4.21859526e+09 -3.74073072e+09
#  -3.81809645e+09 -4.33156853e+09]
# CV_mean:  -4013254639.1068344
# CV Standard Deviation:  213214769.35240448

# %%
CV_r2_scores = cross_val_score(estimator = KNN_regressor,
                               X = train_features_normalized,
                               y = trian_labels,
                               cv = 10,
                               scoring ='r2')
print("CV_r2_scores: ", CV_r2_scores)
# Out:
# CV_r2_scores:  [0.68400717 0.69968474 0.70568826 0.68916112 0.68300347 0.71560054
#  0.68413497 0.7181026  0.71372119 0.67313905]

# %%
CV_r2_scores.mean()
# Out:
# 0.6966243099537704

# %%
CV_r2_scores.std()
# Out:
# 0.015209203198258933

# %%
# Add values to dataframe
K_5_data =[[5, 50586.621, 0.8987, -4013254639.1068, 213214769.35240, 0.6966, 0.01521]]

K_5_df = pd.DataFrame(data=K_5_data, columns = performance_df.columns)

performance_df = pd.concat([performance_df, K_5_df], ignore_index=True)
performance_df
# Out:
#     K  Training MSE  Training Correlation  Mean of 10-Fold CV MSE  \
# 0  10     55743.338              0.875667           -3.912966e+09
# 1   3     44921.724              0.920000           -4.248065e+09
# 2   5     50586.621              0.898700           -4.013255e+09
#
#    std of 10-Fold CV MSE  Mean of 10-Fold CV R2 scores  \
# 0           1.827730e+08                      0.704240
# 1           1.789400e+08                      0.678839
# 2           2.132148e+08                      0.696600
#
#    std of 10-fold R2 scores
# 0                  0.012067
# 1                  0.013231
# 2                  0.015210

# %%
# 7-Nearest Neighbors
import time
start_time = time.time()

KNN_regressor = KNeighborsRegressor(n_neighbors=7, metric = 'euclidean')
KNN_regressor.fit(train_features_normalized, trian_labels)

end_time = time.time()
elapsed_time = end_time - start_time
print("Running time: ", elapsed_time, "seconds")
# Out:
# Running time:  0.02594590187072754 seconds

# %%
training_predictions = KNN_regressor.predict(train_features_normalized)
training_predictions
# Out:
# array([110471.42857143, 178457.14285714, 339428.71428571, ...,
#        283814.28571429, 144042.85714286, 187200.        ])

# %%
training_predictions.shape
# Out:
# (16346,)

# %%
trian_labels.shape
# Out:
# (16346,)

# %%
import pandas as pd
prediction_summary = pd.DataFrame({'predicted_label':training_predictions, 'actual_label':trian_labels})
prediction_summary
# Out:
#        predicted_label  actual_label
# 12346    110471.428571      145200.0
# 19326    178457.142857      117000.0
# 16824    339428.714286      263900.0
# 6869     167842.857143      163700.0
# 16677    180614.285714      236100.0
# ...                ...           ...
# 9372     273042.857143      310300.0
# 7291     184800.000000      255000.0
# 17728    283814.285714      241900.0
# 7293     144042.857143      150000.0
# 17673    187200.000000      191100.0
#
# [16346 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
prediction_summary.plot.scatter(x='predicted_label', y='actual_label', color='blue', marker='o')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Predicted Label vs Actual Label for Training Data')
plt.show()

# %%
import numpy as np
np.corrcoef(training_predictions, trian_labels)
# Out:
# array([[1.        , 0.88627989],
#        [0.88627989, 1.        ]])

# %%
prediction_summary['error'] = prediction_summary['actual_label'] - prediction_summary['predicted_label']
prediction_summary
# Out:
#        predicted_label  actual_label         error
# 12346    110471.428571      145200.0  34728.571429
# 19326    178457.142857      117000.0 -61457.142857
# 16824    339428.714286      263900.0 -75528.714286
# 6869     167842.857143      163700.0  -4142.857143
# 16677    180614.285714      236100.0  55485.714286
# ...                ...           ...           ...
# 9372     273042.857143      310300.0  37257.142857
# 7291     184800.000000      255000.0  70200.000000
# 17728    283814.285714      241900.0 -41914.285714
# 7293     144042.857143      150000.0   5957.142857
# 17673    187200.000000      191100.0   3900.000000
#
# [16346 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error
lin_mse = mean_squared_error(trian_labels, training_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 53449.55657533636

# %%
CV_mse_scores = cross_val_score(estimator = KNN_regressor, X = train_features_normalized, y = trian_labels, cv = 10, scoring = 'neg_mean_squared_error')
print("CV_mse_scores: ", CV_mse_scores)
# Out:
# CV_mse_scores:  [-3.91841608e+09 -4.10790086e+09 -3.59604082e+09 -3.81505352e+09
#  -4.08762578e+09 -3.83463385e+09 -4.10664865e+09 -3.77413013e+09
#  -3.73180413e+09 -4.15740833e+09]

# %%
display_scores(CV_mse_scores)
# Out:
# CV_scores:  [-3.91841608e+09 -4.10790086e+09 -3.59604082e+09 -3.81505352e+09
#  -4.08762578e+09 -3.83463385e+09 -4.10664865e+09 -3.77413013e+09
#  -3.73180413e+09 -4.15740833e+09]
# CV_mean:  -3912966215.784583
# CV Standard Deviation:  182773010.66517955

# %%
CV_r2_scores = cross_val_score(estimator = KNN_regressor,
                               X = train_features_normalized,
                               y = trian_labels,
                               cv = 10,
                               scoring ='r2')
print("CV_r2_scores: ", CV_r2_scores)
# Out:
# CV_r2_scores:  [0.69080821 0.70565108 0.71749391 0.69946592 0.69684798 0.71756461
#  0.69251691 0.71558565 0.72019134 0.68628121]

# %%
CV_r2_scores.mean()
# Out:
# 0.7042406815238087

# %%
CV_r2_scores.std()
# Out:
# 0.01206717541654081

# %%
# Add values to dataframe
K_7_data =[[7, 53449.5566, 0.8863, -3912966215.7845, 182773010.6652, 0.70424068, 0.012067175]]

K_7_df = pd.DataFrame(data=K_7_data, columns = performance_df.columns)

performance_df = pd.concat([performance_df, K_7_df], ignore_index=True)
performance_df
# Out:
#     K  Training MSE  Training Correlation  Mean of 10-Fold CV MSE  \
# 0  10    55743.3380              0.875667           -3.912966e+09
# 1   3    44921.7240              0.920000           -4.248065e+09
# 2   5    50586.6210              0.898700           -4.013255e+09
# 3   7    53449.5566              0.886300           -3.912966e+09
#
#    std of 10-Fold CV MSE  Mean of 10-Fold CV R2 scores  \
# 0           1.827730e+08                      0.704240
# 1           1.789400e+08                      0.678839
# 2           2.132148e+08                      0.696600
# 3           1.827730e+08                      0.704241
#
#    std of 10-fold R2 scores
# 0                  0.012067
# 1                  0.013231
# 2                  0.015210
# 3                  0.012067

# %%
# 11-Nearest Neighbors
import time
start_time = time.time()

KNN_regressor = KNeighborsRegressor(n_neighbors=3, metric = 'euclidean')
KNN_regressor.fit(train_features_normalized, trian_labels)

end_time = time.time()
elapsed_time = end_time - start_time
print("Running time: ", elapsed_time, "seconds")
# Out:
# Running time:  0.02916884422302246 seconds

# %%
training_predictions = KNN_regressor.predict(train_features_normalized)
training_predictions
# Out:
# array([136566.66666667, 149966.66666667, 275700.        , ...,
#        274600.        , 150000.        , 190900.        ])

# %%
training_predictions.shape
# Out:
# (16346,)

# %%
trian_labels.shape
# Out:
# (16346,)

# %%
import pandas as pd
prediction_summary = pd.DataFrame({'predicted_label':training_predictions, 'actual_label':trian_labels})
prediction_summary
# Out:
#        predicted_label  actual_label
# 12346    136566.666667      145200.0
# 19326    149966.666667      117000.0
# 16824    275700.000000      263900.0
# 6869     180500.000000      163700.0
# 16677    203133.333333      236100.0
# ...                ...           ...
# 9372     268300.000000      310300.0
# 7291     204633.333333      255000.0
# 17728    274600.000000      241900.0
# 7293     150000.000000      150000.0
# 17673    190900.000000      191100.0
#
# [16346 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
prediction_summary.plot.scatter(x='predicted_label', y='actual_label', color='blue', marker='o')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Predicted Label vs Actual Label for Training Data')
plt.show()

# %%
import numpy as np
np.corrcoef(training_predictions, trian_labels)
# Out:
# array([[1.        , 0.92096524],
#        [0.92096524, 1.        ]])

# %%
prediction_summary['error'] = prediction_summary['actual_label'] - prediction_summary['predicted_label']
prediction_summary
# Out:
#        predicted_label  actual_label         error
# 12346    136566.666667      145200.0   8633.333333
# 19326    149966.666667      117000.0 -32966.666667
# 16824    275700.000000      263900.0 -11800.000000
# 6869     180500.000000      163700.0 -16800.000000
# 16677    203133.333333      236100.0  32966.666667
# ...                ...           ...           ...
# 9372     268300.000000      310300.0  42000.000000
# 7291     204633.333333      255000.0  50366.666667
# 17728    274600.000000      241900.0 -32700.000000
# 7293     150000.000000      150000.0      0.000000
# 17673    190900.000000      191100.0    200.000000
#
# [16346 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error
lin_mse = mean_squared_error(trian_labels, training_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 44921.72441672835

# %%
CV_mse_scores = cross_val_score(estimator = KNN_regressor, X = train_features_normalized, y = trian_labels, cv = 10, scoring = 'neg_mean_squared_error')
print("CV_mse_scores: ", CV_mse_scores)
# Out:
# CV_mse_scores:  [-4.23722703e+09 -4.33221614e+09 -4.01473040e+09 -4.16385502e+09
#  -4.47043278e+09 -4.19915410e+09 -4.39235917e+09 -3.95327747e+09
#  -4.17509910e+09 -4.54230269e+09]

# %%
display_scores(CV_mse_scores)
# Out:
# CV_scores:  [-4.23722703e+09 -4.33221614e+09 -4.01473040e+09 -4.16385502e+09
#  -4.47043278e+09 -4.19915410e+09 -4.39235917e+09 -3.95327747e+09
#  -4.17509910e+09 -4.54230269e+09]
# CV_mean:  -4248065390.28994
# CV Standard Deviation:  178940010.04488206

# %%
CV_r2_scores = cross_val_score(estimator = KNN_regressor,
                               X = train_features_normalized,
                               y = trian_labels,
                               cv = 10,
                               scoring ='r2')
print("CV_r2_scores: ", CV_r2_scores)
# Out:
# CV_r2_scores:  [0.66565169 0.68957792 0.68460153 0.67198878 0.66845773 0.6907163
#  0.67112449 0.70208531 0.68695332 0.65723701]

# %%
CV_r2_scores.mean()
# Out:
# 0.6788394069479919

# %%
CV_r2_scores.std()
# Out:
# 0.013231006459082454

# %%
# Add values to dataframe
K_11_data =[[11, 44921.7244, 0.9210, -4248065390.28994, 178940010.04488, 0.6788394, 0.013231006]]

K_11_df = pd.DataFrame(data=K_11_data, columns = performance_df.columns)

performance_df = pd.concat([performance_df, K_11_df], ignore_index=True)
performance_df
# Out:
#     K  Training MSE  Training Correlation  Mean of 10-Fold CV MSE  \
# 0  10    55743.3380              0.875667           -3.912966e+09
# 1   3    44921.7240              0.920000           -4.248065e+09
# 2   5    50586.6210              0.898700           -4.013255e+09
# 3   7    53449.5566              0.886300           -3.912966e+09
# 4  11    44921.7244              0.921000           -4.248065e+09
#
#    std of 10-Fold CV MSE  Mean of 10-Fold CV R2 scores  \
# 0           1.827730e+08                      0.704240
# 1           1.789400e+08                      0.678839
# 2           2.132148e+08                      0.696600
# 3           1.827730e+08                      0.704241
# 4           1.789400e+08                      0.678839
#
#    std of 10-fold R2 scores
# 0                  0.012067
# 1                  0.013231
# 2                  0.015210
# 3                  0.012067
# 4                  0.013231

# %% [markdown]
# Question 8

# %%
from sklearn.neighbors import KNeighborsRegressor
KNN_regressor_k1 = KNeighborsRegressor(n_neighbors=1)
KNN_regressor_k1.fit(train_features_normalized, trian_labels)
# Out:
# KNeighborsRegressor(n_neighbors=1)

# %%
training_predictions_knn_1 = KNN_regressor_k1.predict(train_features_normalized)
training_predictions_knn_1
# Out:
# array([145200., 117000., 263900., ..., 241900., 150000., 191100.])

# %%
import matplotlib.pyplot as plt
plt.scatter(training_predictions_knn_1, trian_labels )
plt.xlabel('training_predictions_knn_1', fontsize=15, color="red")
plt.ylabel('train_label', fontsize=15,color="green")
plt.title('Scatter plot for training_predictions_trees and train_label', fontsize=15)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
knn_k1_mse = mean_squared_error(trian_labels, training_predictions_knn_1)
print("Training MSE of model: ",knn_k1_mse)
# Out:
# Training MSE of model:  0.0

# %% [markdown]
# Question 10

# %%
from sklearn.neighbors import KNeighborsRegressor
KNN_regressor = KNeighborsRegressor()

# %%
n_neighbors_list =[1, 3, 5, 7, 9]
metrics_list = ["uniform", "distance"]

KNN_param_grid = {
    'n_neighbors' : n_neighbors_list,
    'weights' : metrics_list
}

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator = KNN_regressor, param_grid = KNN_param_grid, cv = 10, scoring = 'r2', return_train_score = True)

# %%
grid_search.fit(X = train_features_normalized, y = trian_labels)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [1, 3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']},
#              return_train_score=True, scoring='r2')

# %% [markdown]
# Question 11

# %%
grid_search.best_params_
# Out:
# {'n_neighbors': 9, 'weights': 'distance'}

# %%
best_knn_model = grid_search.best_estimator_
best_knn_model
# Out:
# KNeighborsRegressor(n_neighbors=9, weights='distance')

# %%
df_cv = pd.DataFrame(grid_search.cv_results_)
df_cv.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.044871      0.026400         0.055151        0.029544
# 1       0.017974      0.001370         0.024296        0.002361
# 2       0.017743      0.001793         0.031782        0.002195
# 3       0.021390      0.005061         0.037496        0.007982
# 4       0.020587      0.004628         0.043033        0.009940
#
#   param_n_neighbors param_weights                                     params  \
# 0                 1       uniform   {'n_neighbors': 1, 'weights': 'uniform'}
# 1                 1      distance  {'n_neighbors': 1, 'weights': 'distance'}
# 2                 3       uniform   {'n_neighbors': 3, 'weights': 'uniform'}
# 3                 3      distance  {'n_neighbors': 3, 'weights': 'distance'}
# 4                 5       uniform   {'n_neighbors': 5, 'weights': 'uniform'}
#
#    split0_test_score  split1_test_score  split2_test_score  ...  \
# ...

# %% [markdown]
# Question 12

# %%
test_set_clean = test_set.dropna(subset=["total_bedrooms"])
test_set_clean
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20303    -119.18     34.16                12.0        460.0           101.0
# 16966    -122.31     37.55                27.0       3931.0           933.0
# 10623    -117.77     33.67                12.0       4329.0          1068.0
# 6146     -117.95     34.11                29.0       1986.0           448.0
# 2208     -119.87     36.81                 6.0       1891.0           341.0
# ...          ...       ...                 ...          ...             ...
# 3263     -122.88     39.14                20.0       1125.0           231.0
# 11694    -117.98     33.89                18.0       2939.0           437.0
# 1729     -122.34     37.98                33.0       2014.0           410.0
# 5087     -118.28     33.98                45.0       1720.0           416.0
# 6581     -118.20     34.21                40.0       1477.0           228.0
#
# ...

# %%
test_labels = test_set_clean["median_house_value"].copy() # get labels for output label Y
test_features = test_set_clean.drop("median_house_value", axis=1)

# %%
test_features_normalized = scaler.transform(test_features)
test_features_normalized
# Out:
# array([[0.51494024, 0.17215728, 0.21568627, ..., 0.01126713, 0.01677356,
#         0.32954028],
#        [0.20318725, 0.53241233, 0.50980392, ..., 0.05252389, 0.13977964,
#         0.23946566],
#        [0.65537849, 0.12008502, 0.21568627, ..., 0.05353289, 0.16066436,
#         0.27651343],
#        ...,
#        [0.2001992 , 0.5781084 , 0.62745098, ..., 0.03786541, 0.07005427,
#         0.23981738],
#        [0.60458167, 0.15302869, 0.8627451 , ..., 0.03865019, 0.05985858,
#         0.02991683],
#        [0.6125498 , 0.17747078, 0.76470588, ..., 0.01698478, 0.0366716 ,
#         0.5060344 ]])

# %%
best_knn_model = grid_search.best_estimator_
test_predictions_knn = best_knn_model.predict(test_features_normalized)
test_predictions_knn
# Out:
# array([322073.50408291, 251272.92264253, 245313.12434277, ...,
#        230751.62753686, 100492.17440475, 453313.03308345])

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
test_knn_mse = mean_squared_error(test_labels, test_predictions_knn)
test_knn_correlation = np.corrcoef(test_labels, test_predictions_knn)
test_knn_R2 = r2_score(test_labels, test_predictions_knn)
print("MSE: ", test_knn_mse)
print("Correlation: ", test_knn_correlation)
print("R2-score: ", test_knn_R2)
# Out:
# MSE:  3977839840.445325
# Correlation:  [[1.         0.84212456]
#  [0.84212456 1.        ]]
# R2-score:  0.7086637501453643

# %% [markdown]
# Question 13

# %%
from joblib import dump, load
dump(scaler, 'scaler.joblib')
# Out:
# ['scaler.joblib']

# %%
from joblib import dump, load
dump(best_knn_model, 'best_knn_model.joblib')
# Out:
# ['best_knn_model.joblib']

# %%
from joblib import dump, load
scaler_reload = load('scaler.joblib')
print("Scaler Min: ",scaler_reload.data_min_)
print("Scaler Max: ",scaler_reload.data_max_)
# Out:
# Scaler Min:  [-124.35     32.54      1.        2.        1.        3.        1.
#     0.4999]
# Scaler Max:  [-1.14310e+02  4.19500e+01  5.20000e+01  3.93200e+04  6.44500e+03
#   3.56820e+04  6.08200e+03  1.50001e+01]

# %%
from joblib import dump, load
KNN_model_reload = load('best_knn_model.joblib')
KNN_model_reload
# Out:
# KNeighborsRegressor(n_neighbors=9, weights='distance')
